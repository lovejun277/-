# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel(r'疑似死亡时间相隔1年以上一卡通发放记录&疾控中心死亡记录.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7118 entries, 0 to 7117
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   序号      7118 non-null   int64
#  1   对象代码    7118 non-null   int64
#  2   补贴类型    7118 non-null   object
#  3   对象姓名    7118 non-null   object
#  4   身份证号码   7118 non-null   object
#  5   发放账号    7118 non-null   object
#  6   应发金额    7118 non-null   float64
#  7   实发金额    7118 non-null   float64
#  8   发放日期    7118 non-null   object
#  9   家庭地址    7107 non-null   object
#  10  手机号码    3710 non-null   object
#  11  报告单位名称  7118 non-null   object
#  12  死者姓名    7118 non-null   object
#  13  证件号码    7118 non-null   object
#  14  死亡日期    7118 non-null   object
#  15  间隔天数    7118 non-null   int64
# dtypes: float64(2), int64(3), object(11)
# memory usage: 889.9+ KB

# %%
df.shape
# Out:
# (7118, 16)

# %%
df.head(5)
# Out:
#       序号                对象代码                补贴类型 对象姓名               身份证号码  \
# 0   3236  430401005001027001       0134-油茶大县奖励资金  刘三保  430422196308287114
# 1   8374  430401025020035021       0134-油茶大县奖励资金  陈秀英  430422192802282863
# 2  65119  430401002032006014  0146-耕地地力保护补贴单季（内）  何再清  430422196405235615
# 3  92255  430401007002006016  0146-耕地地力保护补贴单季（内）  肖应松  430422195506247717
# 4  92022  430401005001027001  0146-耕地地力保护补贴单季（内）  刘三保  430422196308287114
#
#                 发放账号     应发金额     实发金额        发放日期            家庭地址  \
# 0  81011450005832565  7750.00  7750.00  2021-06-01      泉溪镇喇叭堰村三元组
# 1  81011450012436450  3550.00  3550.00  2021-06-01       柞市镇虎岭村新屋组
# 2  81011450009107430  1288.35  1288.35  2021-10-28  衡南县向阳桥街道富高村长顺组
# 3  81011450006335798   862.05   862.05  2021-10-28       洪山镇扬名村赤里组
# 4  81011450005832565   871.50   871.50  2021-10-28      泉溪镇喇叭堰村三元组
#
#           手机号码    报告单位名称 死者姓名                证件号码                     死亡日期  \
# ...

# %%
for i in df['补贴类型'].unique():
    df[df['补贴类型']==i].to_excel(r'{}.xlsx'.format(i),index=False)

# %%
data = pd.read_excel(basestation,names=["字段1","字段2","c","e"])
